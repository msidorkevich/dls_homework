# %% [markdown]
# <img src="https://static.wixstatic.com/media/66c28f_db7a1ba3e35b4b17a6688472c889b7bf~mv2_d_2777_1254_s_2.png/v1/fill/w_710,h_320,al_c,q_85,usm_0.66_1.00_0.01/logo_yellow_white.webp" width=1000, height=450>
# <h3 style="text-align: center;"><b>Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ</b></h3>

# %% [markdown]
# # Text Summarization
#
# Всем привет! Сегодня мы познакомимся с задачей суммаризации текста на примере генерации "сжатых" новостей. Рассмотрим некоторые базовые решения и познакомимся с архитектурами нейросетей для решения задачи.
# Датасет: gazeta.ru
#
#
# `Ноутбук создан на основе семинара Гусева Ильи на кафедре компьютерной лингвистики ABBYY МФТИ.`
#
# Загрузим датасет и необходимые библиотеки

# %%
# !wget -q https://www.dropbox.com/s/43l702z5a5i2w8j/gazeta_train.txt
# !wget -q https://www.dropbox.com/s/k2egt3sug0hb185/gazeta_val.txt
# !wget -q https://www.dropbox.com/s/3gki5n5djs9w0v6/gazeta_test.txt

# %%
# !pip -q install razdel networkx pymorphy2 nltk rouge==0.3.1 summa
# Out:
#      |████████████████████████████████| 61kB 3.1MB/s
#      |████████████████████████████████| 61kB 5.7MB/s
#      |████████████████████████████████| 8.2MB 7.6MB/s
#   Building wheel for summa (setup.py) ... done

# %% [markdown]
# ## Dataset

# %% [markdown]
# Посмотрим на то, как устроен датасет

# %%
# !head -n 1 gazeta_train.txt
# !cat gazeta_train.txt | wc -l
# !cat gazeta_val.txt | wc -l
# !cat gazeta_test.txt | wc -l
# Out:
# {"url": "https://www.gazeta.ru/financial/2011/11/30/3852658.shtml", "text": "«По итогам 2011 года чистый отток может составить примерно $80 млрд, в следующем году — около $20 млрд. При этом мы ожидаем, что со второго полугодия 2012 года начнется приток капитала», — заявил «Интерфаксу» замминистра экономического развития Андрей Клепач. Официальные прогнозы по выводу капитала из России становятся все пессимистичными: еще летом власти полагали, что из страны уйдет не более $35 млрд, в сентябре Минэкономразвития назвал цифру $50 млрд, в начале ноября Центробанк пересмотрел оценку до $70 млрд. Очередное изменение прогноза было ожидаемо: по расчетам Центробанка , за январь — октябрь чистый отток капитала достиг $64 млрд, причем в последние месяцы он ускорился: в сентябре он составил $14 млрд, в октябре — $13 млрд против среднего ежемесячного оттока в $6—8 млрд в первом полугодии. «После октябрьских данных Минэкономразвития вынуждено было изменить оценку, настаивать на $70 млрд означало ожидать серьезного замедления оттока капитала на непонятно каких причинах», — говорит главный экономист BNP Paribas Юлия Цепляева. «В последние два месяца отток капитала ускорится, на декабрь приходится значительная часть выплат по внешним долгам, что приводит к усилению оттока, особенно если они не рефинансируются новыми кредитами», — соглашается главный экономист ФК «Открытие» Владимир Тихомиров. Прогнозируемый Минэкономразвития отток капитала — один из самых высоких за последние 20 лет. Больше ушло лишь в 2008 году на фоне разрастания финансового кризиса и российско-грузинской войны — $133,7 млрд. В кризисный 2009 год из России утекло $56,1 млрд. Главный фактор ускорения оттока капитала в 2011 году — нестабильность на внешних финансовых рынках и рост опасений относительно второй волны рецессии. «Это реакция на неуверенность, которую генерирует Европа с долговыми проблемами. В случае новой волны глобальной турбулентности Россия — одна из самых уязвимых стран», — говорит Цепляева. Еще одна причина — ослабление рубля. «Привлекательность вложений снижается на фоне того, что рубль перестал укрепляться, а ставки по депозитам достаточно низкие. В результате экспортеры не полностью возвращают экспортную выручку», — говорит Тихомиров. Внутри страны эксперты не видят особых причин для бегства капитала. «Ситуация выглядит достаточно позитивно, очень хорошие макроэкономические результаты за год, особенно на фоне других стран. С политической точки зрения все достаточно понятно и предсказуемо, итог выборов очевиден», — говорит экономист ИК «Тройка Диалог» Антон Струченевский. Тем не менее политический фактор играет роль. «Бизнесу важно не только, кто будет президентом, он ждет ясности с перестановками в правительстве. В наших условиях административный ресурс важнее всего для успешности бизнеса», — говорит Цепляева, добавляя, что отток капитала продолжится до завершения президентских выборов.", "title": "Прогноз не успевает за оттоком", "summary": "В 2011 году из России уйдет $80 млрд, считают в Минэкономразвития. Менее месяца назад Центробанк давал оценку $70 млрд, повысив первоначальный прогноз вдвое. Отток капитала из страны усиливается из-за кризиса в Европе, а в декабре российским компаниям выплачивать внешние долги. На движение капитала повлияли и выборы: несмотря на их предсказуемость, бизнес хочет ясности с перестановками в правительстве.", "date": "2011-11-30 18:33:39"}
# 52400
# 5265
# 5770

# %%
import json
import random

def read_gazeta_records(file_name, shuffle=True, sort_by_date=False):
    assert shuffle != sort_by_date
    records = []
    with open(file_name, "r") as r:
        for line in r:
            records.append(json.loads(line))
    if sort_by_date:
        records.sort(key=lambda x: x["date"])
    if shuffle:
        random.shuffle(records)
    return records

# %%
train_records = read_gazeta_records("gazeta_train.txt")
val_records = read_gazeta_records("gazeta_val.txt")
test_records = read_gazeta_records("gazeta_test.txt")

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

def calc_scores(references, predictions, metric="all"):
    print("Count:", len(predictions))
    print("Ref:", references[-1])
    print("Hyp:", predictions[-1])

    if metric in ("bleu", "all"):
        print("BLEU: ", corpus_bleu([[r] for r in references], predictions))
    if metric in ("rouge", "all"):
        rouge = Rouge()
        scores = rouge.get_scores(predictions, references, avg=True)
        print("ROUGE: ", scores)

# %% [markdown]
# ## Extractive RNN

# %% [markdown]
# ### BPE
# Для начала сделаем BPE токенизацию

# %%
# !pip install youtokentome
# Out:
# Collecting youtokentome
#   Downloading https://files.pythonhosted.org/packages/c8/1c/224cdc3d9a32ed706c8fb1f30b491be6ea5da114ff4edc174014cc24fa43/youtokentome-1.0.6-cp37-cp37m-manylinux2010_x86_64.whl (1.7MB)
#      |████████████████████████████████| 1.7MB 4.2MB/s
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from youtokentome) (7.1.2)
# Installing collected packages: youtokentome
# Successfully installed youtokentome-1.0.6

# %%
import youtokentome as yttm

def train_bpe(records, model_path, model_type="bpe", vocab_size=10000, lower=True):
    temp_file_name = "temp.txt"
    with open(temp_file_name, "w") as temp:
        for record in records:
            text, summary = record['text'], record['summary']
            if lower:
                summary = summary.lower()
                text = text.lower()
            if not text or not summary:
                continue
            temp.write(text + "\n")
            temp.write(summary + "\n")
    yttm.BPE.train(data=temp_file_name, vocab_size=vocab_size, model=model_path)

train_bpe(train_records, "BPE_model.bin")

# %% [markdown]
# ### Словарь
# Составим словарь для индексации токенов

# %%
bpe_processor = yttm.BPE('BPE_model.bin')
vocabulary = bpe_processor.vocab()

# %% [markdown]
# ### Кэш oracle summary
# Закэшируем oracle summary, чтобы не пересчитывать их каждый раз

# %%
from rouge import Rouge
import razdel
from tqdm.notebook import tqdm

import copy

def build_oracle_summary_greedy(text, gold_summary, calc_score, lower=True, max_sentences=30):
    '''
    Жадное построение oracle summary
    '''
    gold_summary = gold_summary.lower() if lower else gold_summary
    # Делим текст на предложения
    sentences = [sentence.text.lower() if lower else sentence.text for sentence in razdel.sentenize(text)][:max_sentences]
    n_sentences = len(sentences)
    oracle_summary_sentences = set()
    
    score = -1.0
    summaries = []
    for _ in range(n_sentences):
        for i in range(n_sentences):
            if i in oracle_summary_sentences:
                continue
            current_summary_sentences = copy.copy(oracle_summary_sentences)
            # Добавляем какое-то предложения к уже существующему summary
            current_summary_sentences.add(i)
            current_summary = " ".join([sentences[index] for index in sorted(list(current_summary_sentences))])
            # Считаем метрики
            current_score = calc_score(current_summary, gold_summary)
            summaries.append((current_score, current_summary_sentences))
        # Если получилось улучшить метрики с добавлением какого-либо предложения, то пробуем добавить ещё
        # Иначе на этом заканчиваем
        best_summary_score, best_summary_sentences = max(summaries)
        if best_summary_score <= score:
            break
        oracle_summary_sentences = best_summary_sentences
        score = best_summary_score
    oracle_summary = " ".join([sentences[index] for index in sorted(list(oracle_summary_sentences))])
    return oracle_summary, oracle_summary_sentences

def calc_single_score(pred_summary, gold_summary, rouge):
    return rouge.get_scores([pred_summary], [gold_summary], avg=True)['rouge-2']['f']

def add_oracle_summary_to_records(records, max_sentences=30, lower=True, nrows=1000):
    rouge = Rouge()
    for i, record in tqdm(enumerate(records)):
        if i >= nrows:
            break
        text = record["text"]
        summary = record["summary"]

        summary = summary.lower() if lower else summary
        sentences = [sentence.text.lower() if lower else sentence.text for sentence in razdel.sentenize(text)][:max_sentences]
        oracle_summary, sentences_indicies = build_oracle_summary_greedy(text, summary, calc_score=lambda x, y: calc_single_score(x, y, rouge),
                                                                         lower=lower, max_sentences=max_sentences)
        record["sentences"] = sentences
        record["oracle_sentences"] = list(sentences_indicies)
        record["oracle_summary"] = oracle_summary

    return records[:nrows]

ext_train_records = add_oracle_summary_to_records(train_records, nrows=2048)
ext_val_records = add_oracle_summary_to_records(val_records, nrows=256)
ext_test_records = add_oracle_summary_to_records(test_records, nrows=256)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ### Составление батчей

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import random
import math
import razdel
import torch
import numpy as np
from rouge import Rouge


class BatchIterator():
    def __init__(self, records, vocabulary, batch_size, bpe_processor, shuffle=True, lower=True, max_sentences=30, max_sentence_length=50, device=torch.device('cpu')):
        self.records = records
        self.num_samples = len(records)
        self.batch_size = batch_size
        self.bpe_processor = bpe_processor
        self.shuffle = shuffle
        self.batches_count = int(math.ceil(self.num_samples / batch_size))
        self.lower = lower
        self.rouge = Rouge()
        self.vocabulary = vocabulary
        self.max_sentences = max_sentences
        self.max_sentence_length = max_sentence_length
        self.device = device
        
    def __len__(self):
        return self.batches_count
    
    def __iter__(self):
        indices = np.arange(self.num_samples)
        if self.shuffle:
            np.random.shuffle(indices)

        for start in range(0, self.num_samples, self.batch_size):
            end = min(start + self.batch_size, self.num_samples)
            batch_indices = indices[start:end]

            batch_inputs = []
            batch_outputs = []
            max_sentence_length = 0
            max_sentences = 0
            batch_records = []

            for data_ind in batch_indices:
                
                record = self.records[data_ind]
                batch_records.append(record)
                text = record["text"]
                summary = record["summary"]
                summary = summary.lower() if self.lower else summary

                if "sentences" not in record:
                    sentences = [sentence.text.lower() if self.lower else sentence.text for sentence in razdel.sentenize(text)][:self.max_sentences]
                else:
                    sentences = record["sentences"]
                max_sentences = max(len(sentences), max_sentences)
                
                # номера предложений, которые в нашем саммари
                if "oracle_sentences" not in record:
                    calc_score = lambda x, y: calc_single_score(x, y, self.rouge)
                    sentences_indicies = build_oracle_summary_greedy(text, summary, calc_score=calc_score, lower=self.lower, max_sentences=self.max_sentences)[1]
                else:   
                    sentences_indicies = record["oracle_sentences"]
                
                # inputs - индексы слов в предложении
                inputs = [bpe_processor.encode(sentence)[:self.max_sentence_length] for sentence in sentences]
                max_sentence_length = max(max_sentence_length, max([len(tokens) for tokens in inputs]))
                
                # получение метки класса предложения
                outputs = [int(i in sentences_indicies) for i in range(len(sentences))]
                batch_inputs.append(inputs)
                batch_outputs.append(outputs)

            tensor_inputs = torch.zeros((self.batch_size, max_sentences, max_sentence_length), dtype=torch.long, device=self.device)
            # we add index 2 for padding
            # YOUR CODE
            tensor_outputs = torch.full((self.batch_size, max_sentences), fill_value=2.0, dtype=torch.float32, device=self.device)

            for i, inputs in enumerate(batch_inputs):
                for j, sentence_tokens in enumerate(inputs):
                    tensor_inputs[i][j][:len(sentence_tokens)] = torch.tensor(sentence_tokens, dtype=torch.int64)

            for i, outputs in enumerate(batch_outputs):
                tensor_outputs[i][:len(outputs)] = torch.LongTensor(outputs)

            tensor_outputs = tensor_outputs.long()

            yield {
                'inputs': tensor_inputs,
                'outputs': tensor_outputs,
                'records': batch_records
            }

# %%
train_iterator = BatchIterator(ext_train_records, vocabulary, 32, bpe_processor, device=device)
val_iterator = BatchIterator(ext_val_records, vocabulary, 32, bpe_processor, device=device)
test_iterator = BatchIterator(ext_test_records, vocabulary, 32, bpe_processor, device=device)

# %% [markdown]
# ## Extractor -  SummaRuNNer
#  https://arxiv.org/pdf/1611.04230.pdf

# %% [markdown]
# ### Homework
#
# * В данной реализации в `outputs` в качестве padding используется индекс 0. Измените в функции \_\_iter__ индекс padding, чтобы он не совпадал с классом 0 или 1, например, 2.
# * В качестве criterion используйте `CrossEntropyLoss`вместо `BCEWithLogitsLoss`
# * Из-за смены criterion, вы уже должны подавать на вход criterion ни одно число, а logits для каждого класса. Перед подачей logits вы можете отфильтровать предсказания для класса padding. В этом пункте вам придется изменять файл `train_model.py`, а именно функциии `train` и `evaluate`.
# * Используйте два варианта обучения: c весами в `CrossEntropyLoss` и без
# * Также сравните `inference`, когда вы ранжируете logits, и когды вы выбирате предложения, у котрых logits > 0, в двух вариантах обучения.
# * Реализуйте дополнительно характеристику предложения `novelty`. Как влияет добавление `novelty` на качество summary?
# * Постарайтесь улучшить качество модели, полученной на семинаре: $BLEU \approx 0.45$

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

from torch.nn.utils.rnn import pack_padded_sequence as pack
from torch.nn.utils.rnn import pad_packed_sequence as unpack

class SentenceEncoderRNN(nn.Module):
    def __init__(self, input_size, embedding_dim, hidden_size, n_layers=3, dropout=0.3, bidirectional=True):
        super().__init__()

        num_directions = 2 if bidirectional else 1
        assert hidden_size % num_directions == 0
        hidden_size = hidden_size // num_directions

        self.embedding_dim = embedding_dim
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.bidirectional = bidirectional

        self.embedding_layer = nn.Embedding(input_size, embedding_dim)
        self.rnn_layer = nn.LSTM(embedding_dim, hidden_size, n_layers, dropout=dropout, bidirectional=bidirectional, batch_first=True)
        self.dropout_layer = nn.Dropout(dropout)

    def forward(self, inputs, hidden=None):
        embedded = self.dropout_layer(self.embedding_layer(inputs))
        outputs, _ = self.rnn_layer(embedded, hidden)
        sentences_embeddings = torch.mean(outputs, 1)
        # [batch_size, hidden_size]
        return sentences_embeddings

class SentenceTaggerRNN(nn.Module):
    def __init__(self,
                 vocabulary_size,
                 use_content=True,
                 use_salience=True,
                 use_novelty=True,
                 token_embedding_dim=128,
                 sentence_encoder_hidden_size=256,
                 hidden_size=256,
                 bidirectional=True,
                 sentence_encoder_n_layers=2,
                 sentence_encoder_dropout=0.3,
                 sentence_encoder_bidirectional=True,
                 n_layers=2,
                 dropout=0.3):
        
        super().__init__()

        num_directions = 2 if bidirectional else 1
        assert hidden_size % num_directions == 0
        hidden_size = hidden_size // num_directions

        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.bidirectional = bidirectional

        self.sentence_encoder = SentenceEncoderRNN(vocabulary_size, token_embedding_dim,
                                                   sentence_encoder_hidden_size, sentence_encoder_n_layers, 
                                                   sentence_encoder_dropout, sentence_encoder_bidirectional)
        
        self.rnn_layer = nn.LSTM(sentence_encoder_hidden_size, hidden_size, n_layers, dropout=dropout,
                           bidirectional=bidirectional, batch_first=True)
        
        self.dropout_layer = nn.Dropout(dropout)
        self.content_linear_layer = nn.Linear(hidden_size * 2, 1)
        self.document_linear_layer = nn.Linear(hidden_size * 2, hidden_size * 2)
        self.salience_linear_layer = nn.Linear(hidden_size * 2, hidden_size * 2)
        self.novelty_linear_layer = nn.Linear(hidden_size * 2, hidden_size * 2)
        self.tanh_layer = nn.Tanh()

        self.use_content = use_content
        self.use_salience = use_salience
        self.use_novelty = use_novelty

    def forward(self, inputs, hidden=None):
        # parameters of the probability
        content = 0
        salience = 0
        novelty = 0

        # [batch_size, seq num, seq_len]
        batch_size = inputs.size(0)
        sentences_count = inputs.size(1)
        tokens_count = inputs.size(2)
        inputs = inputs.reshape(-1, tokens_count)
        # [batch_size * seq num, seq_len]

        embedded_sentences = self.sentence_encoder(inputs)
        embedded_sentences = self.dropout_layer(embedded_sentences.reshape(batch_size, sentences_count, -1))
        # [batch_size *  seq num, seq_len, hidden_size] -> [batch_size, seq num, hidden_size]

        outputs, _ = self.rnn_layer(embedded_sentences, hidden)
        # [batch_size, seq num, hidden_size]

        document_embedding = self.tanh_layer(self.document_linear_layer(torch.mean(outputs, 1)))
        # [batch_size, hidden_size]

        # W * h^T
        if self.use_content:
            content = self.content_linear_layer(outputs).squeeze(2) # 1-representation
        # [batch_size, seq num]

        # h^T * W * d
        if self.use_salience:
            salience = torch.bmm(outputs, self.salience_linear_layer(document_embedding).unsqueeze(2)).squeeze(2) # 2-representation
        # [batch_size, seq num, hidden_size] * [batch_size, hidden_size, 1] = [batch_size, seq num, ]

        if self.use_novelty:
            # at every step add novelty to prediction of the sentence
            predictions = content + salience
            
            # 0) initialize summary_representation and novelty by zeros
            # YOUR CODE
            summary_representation = torch.zeros(batch_size, self.hidden_size * 2).to(device) #[batch_size, hidden_size]
            novelty = torch.zeros(batch_size, sentences_count)

            for sentence_num in range(sentences_count):

                # 1) take sentence_num_state from outputs(representation of the sentence with number sentence_num)
                # 2) calculate novelty for current sentence
                # 3) add novelty to predictions
                # 4) calculcate probability for current sentence
                # 5) add sentence_num_state with the weight which is equal to probability to summary_representation

                # YOUR CODE 
                sentence_num_state = outputs[:, sentence_num, :] #1

                novelty = torch.bmm(outputs, self.novelty_linear_layer(torch.tanh(summary_representation)).unsqueeze(2)).squeeze(2) #2
                # [batch_size, seq num, hidden_size] * [batch_size, hidden_size, 1] = [batch_size, seq num, ]

                predictions[:, sentence_num] += novelty[:, sentence_num] #3

                probability = torch.sigmoid(predictions)[:, sentence_num].unsqueeze(1) #4

                summary_representation += probability * sentence_num_state  #5

        return content + salience + novelty

# %% [markdown]
# ## Model
# $P\left(y_{j} = 1 \mid \mathbf{h}_{j}, \mathbf{s}_{j}, \mathbf{d}\right)=\sigma\left(W_{c} \mathbf{h}_{j} + \mathbf{h}_{j}^{T} W_{s} \mathbf{d}\right)$
# --------------------

# %%
#!gdown https://drive.google.com/uc?id=1MiS_iczALcyF7zGDPY6niyeD82P0_PBH -O train_model.py

from google.colab import drive
drive.mount('/content/drive')

# !cp /content/drive/MyDrive/hw_text_summarization/train_model.py .

import train_model
import imp 
imp.reload(train_model)
from train_model import train_with_logs
# Out:
# Mounted at /content/drive

# %%
all_counts = torch.zeros(3)
for batch in iter(train_iterator):
    all_counts += batch['outputs'].view(-1).unique(return_counts=True)[1].cpu()

class_0_count = all_counts[0]
class_1_count = all_counts[1]

print("class_0_count=", class_0_count)
print("class_1_count=", class_1_count)

weights = torch.tensor([class_1_count / (class_0_count + class_1_count), class_0_count / (class_0_count + class_1_count)])
weights = weights.to(device)
weights
# Out:
# class_0_count= tensor(53811.)
# class_1_count= tensor(4620.)
# tensor([0.0791, 0.9209], device='cuda:0')

# %%
N_EPOCHS = 20
CLIP = 1

def train_all(use_class_weights, N_EPOCHS, CLIP, lr=1e-3):
    optimizer = optim.Adam(model.parameters(), lr)
    if use_class_weights:
        # weights depend on the number of objects of class 0 and 1
        criterion = nn.CrossEntropyLoss(weight=weights, ignore_index=2)
    else:
        criterion = nn.CrossEntropyLoss(ignore_index=2)
    train_with_logs(model, train_iterator, val_iterator, optimizer, criterion, N_EPOCHS, CLIP)

# %% [markdown]
# ## Inference

# %%
from train_model import punct_detokenize, postprocess

def top_k_inference_summarunner(model, iterator, top_k=3):
    print("top_k=", top_k)

    references = []
    predictions = []

    model.eval()
    for batch in test_iterator:

        preds = model(batch['inputs'])
        sum_in = torch.argsort(preds, dim=1)[:, -top_k:]
        
        for i in range(len(batch['outputs'])):

            summary = batch['records'][i]['summary'].lower()
            pred_summary = ' '.join([batch['records'][i]['sentences'][ind] for ind in sum_in.sort(dim=1)[0][i]])

            summary, pred_summary = postprocess(summary, pred_summary)

            references.append(summary)
            predictions.append(pred_summary)

    calc_scores(references, predictions)

# %%
def threshold_inference_summarunner(model, iterator, threshold=0):
    print("threshold", threshold)

    references = []
    predictions = []

    model.eval()
    for batch in test_iterator:

        preds = model(batch['inputs'])
        
        for i in range(len(batch['outputs'])):
            sentences = (preds[i] > threshold).nonzero(as_tuple=True)[0].unique()

            summary = batch['records'][i]['summary'].lower()
            pred_summary = ' '.join([batch['records'][i]['sentences'][ind] for ind in sentences if ind < len(batch['records'][i]['sentences'])])

            if len(pred_summary) == 0:
                pred_summary = ' '.join(batch['records'][i]['sentences'])

            summary, pred_summary = postprocess(summary, pred_summary)

            references.append(summary)
            predictions.append(pred_summary)

    calc_scores(references, predictions)

# %%
vocab_size = len(vocabulary)

# %% [markdown]
# ## Обучим модель без весов и оценим ее качество

# %%
model = SentenceTaggerRNN(vocab_size, use_novelty=False).to(device)

train_all(False, N_EPOCHS, CLIP)

model.load_state_dict(torch.load('best-val-model.pt'))

top_k_inference_summarunner(model, test_iterator, 1)
top_k_inference_summarunner(model, test_iterator, 2)
top_k_inference_summarunner(model, test_iterator, 3)
top_k_inference_summarunner(model, test_iterator, 5)
threshold_inference_summarunner(model, test_iterator, 0.2)
threshold_inference_summarunner(model, test_iterator, 0.3)
threshold_inference_summarunner(model, test_iterator, 0.35)
threshold_inference_summarunner(model, test_iterator, 0.4)
threshold_inference_summarunner(model, test_iterator, 0.5)
# Out:
# Epoch: 20 | Time: 0m 8s
# 	Train Loss: 0.071 | Train PPL:   1.073
# 	 Val. Loss: 0.515 |  Val. PPL:   1.673
# top_k= 1
# Count: 256
# Ref: убийство пентагоном главы спецназа « аль-кудс » ирана касема сулеймани может серьезно обострить ситуацию в ближневосточном регионе — к такому выводу пришли президенты россии владимир путин и франции эммануэль макрон в телефонном разговоре . в тот же день глава мид россии сергей лавров и госсекретарь сша майк помпео обсудили по телефону атаку на сулеймани , и в ходе беседы российский министр раскритиковал действия вашингтона .
# Hyp: президенты россии владимир путин и франции эммануэль макрон в телефонном разговоре , прошедшем в пятницу , 3 января , выразили озабоченность по поводу ликвидации американскими военными командующего силами специального назначения « аль-кудс » корпуса стражей исламской революции ирана касема сулеймани .
# BLEU:  0.1951617055764109
# ROUGE:  {'rouge-1': {'f': 0.27999793835109166, 'p': 0.44137925025270525, 'r': 0.21734463160292056}, 'rouge-2': {'f': 0.13960692179339343, 'p': 0.2252523034115662, 'r': 0.10789084125917864}, 'rouge-l': {'f': 0.20939310777214343, 'p': 0.3939901019557496, 'r': 0.19330830705774915}}
# top_k= 2
# Count: 256
# Ref: сахалинская и магаданская области были названы самыми « пьющими » регионами россии за 2019 год . в топ-5 также вошли республика коми , чукотка и карелия . эксперты объясняют уровень потребления водки не только холодным климатом , но и высокими средними зарплатами , которые позволяют приобретать именно легальный алкоголь . региональные власти также отмечают , что высокие показатели стали следствием « обеления » алкорынка и ликвидации нелегальных продаж .
# Hyp: названы регионы , где пьют больше всего водки . среди лидеров рейтинга — сахалинская и магаданская области ( 12 и 11,5 л водки на душу населения в год ) .
# BLEU:  0.42867053203944355
# ROUGE:  {'rouge-1': {'f': 0.30897024493067454, 'p': 0.34477091540718274, 'r': 0.29687727248350937}, 'rouge-2': {'f': 0.14464002738736406, 'p': 0.15990398437415757, 'r': 0.1426943139813192}, 'rouge-l': {'f': 0.26112008219834293, 'p': 0.30952704165378203, 'r': 0.26582078876497567}}
# top_k= 3
# Count: 256
# Ref: актеры колин фаррелл и энди серкис могут сыграть в новом фильме о бэтмене . по данным сми , первый рассматривается на роль пингвина , тогда как второй — дворецкого альфреда . кроме того , к звездному составу может присоединиться мэттью макконахи . если слухи подтвердятся , поклонников ждет по-настоящему внушительный каст : уже известно , что на главную роль утвержден роберт паттинсон , женщину-кошку исполнит зои кравиц , а злодея загадочника — пол дано .
# Hyp: актеры колин фаррелл и энди серкис ведут переговоры , чтобы сняться в новом фильме о супергерое бэтмене , передает variety со ссылки на источники . по информации издания , фаррелл может сыграть пингвина . до него в роли злодея предстали дэнни де вито в картине « бэтмен возвращается » и робин лорд тейлор в сериале « готэм » .
# BLEU:  0.43134285190491656
# ROUGE:  {'rouge-1': {'f': 0.30227019251814835, 'p': 0.28166637271609773, 'r': 0.34496439737600176}, 'rouge-2': {'f': 0.13488600921636967, 'p': 0.1224499666258892, 'r': 0.16186738536338266}, 'rouge-l': {'f': 0.2566365952951387, 'p': 0.2530579118723991, 'r': 0.30945879028263823}}
# top_k= 5
# Count: 256
# Ref: часы судного дня , символизирующие самые опасные периоды времени для человечества , перевели на 20 секунд ближе к полуночи . причины этому : возросшая опасность ядерной войны , катастрофическое изменения климата из-за неразумной экологической политики крупных стран , а также враждебность в киберпространстве . для улучшения ситуации лидеры сша и россии должны вернуться за стол переговоров и остановить гонку вооружения , а также восстановить действие международных ядерных договоров .
# Hyp: условные часы судного дня , символизирующие самые опасные периоды времени для человечества , перевели на 20 секунд ближе к полуночи — условной точке конца мира . причины такого решения поясняются в заявлении , опубликованном в бюллетене ученых-атомщиков . « человечеству по-прежнему угрожает одновременно две опасности — ядерная война и изменение климата , которые усугубляются информационной войной в киберпространстве , подрывающей способность общества реагировать на угрозы . « осведомленность общественности о климатическом кризисе выросла в 2019 году в основном из-за массовых акций протеста со стороны молодежи во всем мире . на совещаниях оон по климату в прошлом году национальные делегаты выступили с речами .
# BLEU:  0.30663008640543626
решением своих бесконечных личных и ментальных проблем . по сравнению с этой документальной работой о принце чарльзе лента о принце гарри и меган маркл , и без того подвергавшаяся критике , теперь выглядит и вовсе провальной . в начале недели на том же телеканале показали фильм о герцогах , снятый журналистом томом брэдби — « гарри и меган : африканское путешествие » . в картине о недавней 10-дневной поездке в южную африку меган маркл рассказывала о трудностях , с которыми столкнулась , будучи беременной , и о том , как тяжело королевские обязанности ей даются после рождения ребенка . герцогиня сассекская возмущалась , что во время и после ее беременности в британских сми выходило множество негативных материалов о ней и ее муже . супруга принца гарри отметила , что на ее месте любая женщина почувствовала бы себя « действительно уязвимой » , в особенности готовясь стать матерью . в после вопроса журналиста о ее самочувствии бывшая актриса отметила , что « немногие интересуются тем , как у нее дела » . в заключение интервью меган маркл и вовсе заявила , что « существует , а не живет » из-за непрекращающихся проверок на прочность от сми и общества , подтвердив слова интервьюера о том , что в такой ситуации « жизнь может превратиться в настоящую борьбу » . публичные жалобы меган не просто не помогли британцам взглянуть на жизнь герцогов под другим углом и дать им выдохнуть , но лишь усугубили ситуацию . команда пиар-специалистов и кризисных менеджеров из сша , которую герцогиня создала после того , как репутацию сассексов сильно подкосил скандал с перелетами бизнес-джетами , снова просчиталась . « дорогие герцог и герцогиня сассекские , руководство « how to » для вас обоих . документальный фильм о работе принца чарльза , а не о нем . урок , как быть членом королевской семьи . примите во внимание » , — написал один из пользователей twitter о фильме чарльза . мысль поддержал и другой комментатор , заявивший : « обожаю принца чарльза и камиллу . какой замечательный мужчина . нам нужно узнать больше о нашем будущем короле . забудьте о меган , это так скучно » . один из фермеров-арендаторов , проживающий в корнуолле , также положительно отозвался о чарльзе : « у него нет к нам ни милости , ни благодати , он один из нас . я полагаю , что многие люди не знают его с этой стороны » . помимо внесения ясности в ситуацию с тем , что именно « молодые » виндзоры делают не так для британских граждан , фильм также дал хорошее представление о тех ...
# BLEU:  0.08012390202681806
# ROUGE:  {'rouge-1': {'f': 0.14718387144106973, 'p': 0.08339247108591004, 'r': 0.65808944818404}, 'rouge-2': {'f': 0.053453387435332546, 'p': 0.029343260042602456, 'r': 0.31931381537757747}, 'rouge-l': {'f': 0.07883763140891956, 'p': 0.07759106640925131, 'r': 0.61194327288723}}

# %% [markdown]
# ## Обучим модель с весами и оценим ее качество

# %%
model = SentenceTaggerRNN(vocab_size, use_novelty=False).to(device)

train_all(True, N_EPOCHS, CLIP)

model.load_state_dict(torch.load('best-val-model.pt'))

top_k_inference_summarunner(model, test_iterator, 1)
top_k_inference_summarunner(model, test_iterator, 2)
top_k_inference_summarunner(model, test_iterator, 3)
top_k_inference_summarunner(model, test_iterator, 5)
threshold_inference_summarunner(model, test_iterator, 0.2)
threshold_inference_summarunner(model, test_iterator, 0.3)
threshold_inference_summarunner(model, test_iterator, 0.35)
threshold_inference_summarunner(model, test_iterator, 0.4)
threshold_inference_summarunner(model, test_iterator, 0.5)
# Out:
# Epoch: 20 | Time: 0m 8s
# 	Train Loss: 0.180 | Train PPL:   1.198
# 	 Val. Loss: 1.905 |  Val. PPL:   6.720
# top_k= 1
# Count: 256
# Ref: неандертальцы хоронили собратьев , соблюдая определенные ритуалы , считают ученые . новая находка позволяет предположить , что неандертальцы создавали подобия могил , а более ранние данные указывают на то , что , возможно , при погребениях использовались цветы .
# Hyp: неандертальцы хоронили мертвецов с особыми ритуалами , считает команда исследователей под руководством специалистов из кембридского университета .
# BLEU:  0.1974612047722521
# ROUGE:  {'rouge-1': {'f': 0.2816651701712057, 'p': 0.44265913216514763, 'r': 0.21911648617808385}, 'rouge-2': {'f': 0.14088060542198771, 'p': 0.22634890714244005, 'r': 0.10919055716826959}, 'rouge-l': {'f': 0.2109489572734253, 'p': 0.3949881966030381, 'r': 0.19480953254794517}}
# top_k= 2
# Count: 256
# Ref: убийство иранского генерала сулеймани , барическая пила от вильфанда , поражение сборной россии в финале молодежного чемпионата мира по хоккею — что интересовало телеграм-каналы на прошлой неделе .
# Hyp: начнем с главного события новогодних дней — убийства американцами иранского генерала сулеймани иа « стекломой » называет его культовой фигурой шиитского мира . « с его деятельностью связывают практически всю « силовую » политику ирана последних десятилетий : от ирано-иракской войны до уничтожения ( запрещенного в россии ) иг ( организация запрещена в россии ) в сирии и ираке .
# BLEU:  0.4313127726205193
# ROUGE:  {'rouge-1': {'f': 0.3087075074591505, 'p': 0.34382112511256513, 'r': 0.2977321270053813}, 'rouge-2': {'f': 0.14450677226244504, 'p': 0.1593672053278618, 'r': 0.1431857683675643}, 'rouge-l': {'f': 0.2610373441648967, 'p': 0.30918118115283805, 'r': 0.26695466524318784}}
# top_k= 3
# Count: 256
# Ref: президент россии владимир путин одобрил идею создания парламентского измерения « нормандского формата » . этот план он обсудил на встрече с лидером украинской партии « оппозиционная платформа — за жизнь » виктором медведчуком .
# Hyp: президент россии владимир путин поддержал идею создать парламентское измерение « нормандского формата » с участием представителей россии , украины , германии и франции . « конечно , если парламентарии на украине , в россии , в германии и во франции поддержат то , что делается на уровне исполнительной власти , мне кажется , это было бы очень хорошо , к месту » , — заявил путин на встрече с председателем госдумы вячеславом володиным и лидером украинской партии « оппозиционная платформа — за жизнь » виктором медведчуком . медведчук попросил президента россии рассказать об этом предложении французскому коллеге эммануэлю макрону и канцлеру германии ангеле меркель .
# BLEU:  0.438240809826854
# ROUGE:  {'rouge-1': {'f': 0.3074368717556921, 'p': 0.288026038566058, 'r': 0.34970813507713067}, 'rouge-2': {'f': 0.13847465439976842, 'p': 0.12647903850756528, 'r': 0.16550432589557212}, 'rouge-l': {'f': 0.2617938047193847, 'p': 0.259485949379002, 'r': 0.31485224971023074}}
# top_k= 5
# Count: 256
# Ref: репутация принца гарри и меган маркл , вопреки стараниям нанятых голливудских пиарщиков , снова подорвана . на этот раз исправить имидж им помешал принц чарльз , выпустивший образцовый документальный фильм о своей работе .
# Hyp: у принца чарльза вышел новый документальный фильм : многие зрители остались в восторге после просмотра , что не очень благотворно сказалось на репутации герцогов сассекских , которые в последнее время активно стараются завоевать народную любовь . об этом сообщает daily mail . первая серия фильма появилась в сети вечером 24 октября . за это время картину успели посмотреть уже несколько сотен тысяч пользователей . в двухсерийном документальном фильме « принц чарльз : внутри герцогства корнуолл » рассказывается о недвижимости 70-летнего герцога корнуольского , которая суммарно занимает более 50 тыс . гектаров в 23 графствах по всей стране .
# BLEU:  0.32170864129426974
# ROUGE:  {'rouge-1': {'f': 0.28857712733472674, 'p': 0.22581847911122052, 'r': 0.4222145618859919}, 'rouge-2': {'f': 0.12361309054852165, 'p': 0.09322026152706815, 'r': 0.1975091272747683}, 'rouge-l': {'f': 0.22335417008519234, 'p': 0.2035698559417478, 'r': 0.3801416539576963}}
# threshold 0.2
# Count: 256
# Ref: общее количество ядерных снарядов сша на сегодняшний день составляет примерно 5,8 тыс . единиц , сообщают сми . при этом , согласно докладу стокгольмского международного института исследования проблем мира , на январь прошлого года этот показатель был на уровне 6185 . в россии на тот же период ядерных снарядов было около 6,5 тыс . на долю москвы и вашингтона приходится более 90 % всего ядерного оружия в мире .
# Hyp: на сегодняшний день в распоряжении сша есть 1750 развернутых ядерных боеголовок и 2050 — в резерве , сообщает журнал bulletin of the atomic scientists . там отметили , что демонтаж сейчас ожидает примерно 2 тыс . боеголовок , то есть общее число снарядов доходит до 5,8 тыс . по информации издания , из 1750 развернутых боеголовок 400 предназначены для межконтинентальных баллистических ракет , около 900 — для подводных лодок , 300 находятся в сша на базах бомбардировщиков , а остальные 150 — на европейских объектах . в публикации уточнили , что американское ядерное оружие хранится примерно в 24 локациях в 11 штатах государства и пяти европейских странах .
# BLEU:  0.3958235242238529
# ROUGE:  {'rouge-1': {'f': 0.30203002686923963, 'p': 0.27491374920552103, 'r': 0.36627226061335477}, 'rouge-2': {'f': 0.13397413392450638, 'p': 0.11821420361416922, 'r': 0.17417711470529862}, 'rouge-l': {'f': 0.24901514150979362, 'p': 0.2468199042806463, 'r': 0.328918455562671}}
# threshold 0.3
# Count: 256
# Ref: в москве задержали следователя по особо важным делам , который получил взятку в размере 4,3 млн руб . по данным столичного главка ск , сотрудник правоохранительных органов получил деньги от родственника одного из обвиняемых , проходящего по уголовному делу . взамен следователь обещал не привлекать его к уголовной ответственности .
# Hyp: в москве задержан следователь по особо важным делам — его обвиняют в получение взятки в 4,3 млн руб . ( часть 6 статьи 290 ук рф ) , сообщили в пресс-службе столичного главка ск . « 4 февраля следователь получил от лица , действующего под контролем сотрудников правоохранительных органов , взятку в размере 4,3 млн рублей . незаконное денежное вознаграждение предназначалось за непривлечение к уголовной ответственности его родственника по иным эпизодам преступной деятельности в рамках уголовного дела , находящегося в производстве должностного лица » , — заявили в ведомстве , отметив , что взятку получал сотрудник управления по северо-восточному административному округу москвы . в сообщении также говорится , что фигурант дела был задержан в результате совместной работы столичного главка ск и уфсб по москве и области .
# BLEU:  0.4413881831722294
# ROUGE:  {'rouge-1': {'f': 0.30694699210644405, 'p': 0.3015612883445815, 'r': 0.3404240100625231}, 'rouge-2': {'f': 0.13994962673129924, 'p': 0.1344931744064152, 'r': 0.16331635622352147}, 'rouge-l': {'f': 0.25684223295355857, 'p': 0.2704083878031841, 'r': 0.305395089307927}}
# threshold 0.35
# Count: 256
# Ref: киев возбудил уголовные дела по фактам пыток жителей днр со стороны сбу и батальона « азов » , сообщают сми . отмечается , что пленные в течение пяти лет были подозреваемыми в причастности к боестолкновениям в мариуполе 9 мая 2014 года . в итоге они стали участниками обмена пленными между киевом и донбассом , который состоялся 29 декабря .
# Hyp: четверым дончанам , которые участвовали в обмене пленными между киевом и донбассом , за годы в сизо мариуполя удалось добиться от украинских властей начала уголовного производства по фактам пыток со стороны сбу и батальона « азов » , рассказали риа « новости » сами задержанные и их адвокат . киев подозревал вячеслава бирюкова , александра стельниковича , виктора скрипника и евгения дружинина в причастности к боестолкновениям в мариуполе 9 мая 2014 года . по версии украинских правоохранителей , они входили в группу олега недавнего с позывным мангуст .
# BLEU:  0.45925733188041684
# ROUGE:  {'rouge-1': {'f': 0.3072571766915961, 'p': 0.31506144333158714, 'r': 0.3268218399090358}, 'rouge-2': {'f': 0.14070222477450076, 'p': 0.14145283382439577, 'r': 0.15668780442781538}, 'rouge-l': {'f': 0.25707409995468855, 'p': 0.2819910599762096, 'r': 0.29271059603390936}}
# threshold 0.4
# Count: 256
# Ref: « зенит » во второй раз в сезоне проиграл « лейпцигу » в лиге чемпионов . не помогла петербуржцам даже система var , после использования которой рефери встречи отменил один из мячей в ворота хозяев . главный тренер сине-бело-голубых сергей семак считает , что его команда по уровню слабее соперника .
# Hyp: групповой этап лиги чемпионов перешагнул экватор , и в большинстве групп перспективы команд становятся все более очевиднее . в матче 4-го тура петербургский « зенит » на своем поле принимал « рб лейпциг » , в конечном итоге уступив немцам со счетом 0 : 2 .
# BLEU:  0.4737148796685758
# ROUGE:  {'rouge-1': {'f': 0.3054517502410879, 'p': 0.32253408614753637, 'r': 0.3148950539984432}, 'rouge-2': {'f': 0.13920316923559908, 'p': 0.1445645750781382, 'r': 0.14951262897103648}, 'rouge-l': {'f': 0.25568868651173227, 'p': 0.2880828012019935, 'r': 0.2816240293119859}}
# threshold 0.5
# Count: 256
# Ref: в красноярском крае обрушилась не одна , а пять дамб , и произошло это предположительно из-за нарушений в ходе золотодобывающих работ , рассказали в ск . кроме того , владелец прииска допускал выброс вредных веществ в атмосферу и устраивал несанкционированные свалки с мусором . по открытому следствием делу уже прошли первые задержания .
# Hyp: нарушения при проведении золотодобывающих работ стали причиной разрушения технологических дамб на реке сейба на территории золотодобывающего рудника недалеко от поселка щетинкино курагинского района красноярского края , считает следственный комитет . кроме того , стало известно , что дамб было пять , а не одна , как предполагалось изначально .
# BLEU:  0.42591466928428956
# ROUGE:  {'rouge-1': {'f': 0.3071004142740477, 'p': 0.35067611674133176, 'r': 0.2959382973522103}, 'rouge-2': {'f': 0.14338541761117518, 'p': 0.1637351351260641, 'r': 0.14207850005130615}, 'rouge-l': {'f': 0.25582983956350214, 'p': 0.31507586788095093, 'r': 0.2648864588096467}}

# %% [markdown]
# ## Обучим модель c novelty и без весов и оценим ее качество

# %%
model = SentenceTaggerRNN(vocab_size, use_novelty=True).to(device)

train_all(False, N_EPOCHS, CLIP)

model.load_state_dict(torch.load('best-val-model.pt'))

top_k_inference_summarunner(model, test_iterator, 1)
top_k_inference_summarunner(model, test_iterator, 2)
top_k_inference_summarunner(model, test_iterator, 3)
top_k_inference_summarunner(model, test_iterator, 5)
threshold_inference_summarunner(model, test_iterator, 0.2)
threshold_inference_summarunner(model, test_iterator, 0.3)
threshold_inference_summarunner(model, test_iterator, 0.35)
threshold_inference_summarunner(model, test_iterator, 0.4)
threshold_inference_summarunner(model, test_iterator, 0.5)
# Out:
# Epoch: 20 | Time: 0m 9s
# 	Train Loss: 0.071 | Train PPL:   1.074
# 	 Val. Loss: 0.493 |  Val. PPL:   1.637
# top_k= 1
# Count: 256
# Ref: резкое похолодание придет в москву в конце следующей недели . несмотря на по-весеннему теплые рабочие будни , ближе к выходным ситуация кардинально изменится . по словам синоптиков , уже с четверга столицу начнет засыпать снегом , а столбики термометров опустятся до отметки в -8 °c . при этом на сколько морозная погода задержится в регионе метеорологи , пока умалчивают .
# Hyp: резкое похолодание после аномального тепла придет в центральные и северо-западные регионы страны .
# BLEU:  0.1974612047722521
# ROUGE:  {'rouge-1': {'f': 0.2816651701712058, 'p': 0.4426591321651474, 'r': 0.21911648617808394}, 'rouge-2': {'f': 0.14088060542198758, 'p': 0.2263489071424402, 'r': 0.10919055716826961}, 'rouge-l': {'f': 0.2109489572734253, 'p': 0.39498819660303797, 'r': 0.19480953254794528}}
# top_k= 2
# Count: 256
# Ref: в тегеране и в других городах ирана продолжаются массовые протесты , спровоцированные крушением украинского самолета . протестующие , в основном молодые люди , требуют наказать виновных и считают , что ответственность за произошедшее должен взять на себя высший руководитель ирана али хаменеи . вашингтон оказывает моральную поддержку протестующим , пытаясь использовать их гнев для расшатывания системы . вскоре в иране должны пройти выборы в парламент , и их исход теперь предсказать трудно .
# Hyp: на выходных в иране начались массовые протесты . их участники , в основном молодежь , вначале просто несли цветы и свечи в память о погибших , однако вскоре акция памяти переросла в антиправительственные акции .
# BLEU:  0.4314597064479413
# ROUGE:  {'rouge-1': {'f': 0.30840827091653034, 'p': 0.3433652469661117, 'r': 0.2975622900488598}, 'rouge-2': {'f': 0.14441688650970824, 'p': 0.15926624164693493, 'r': 0.14310604897980914}, 'rouge-l': {'f': 0.2606923589415858, 'p': 0.3086761396768654, 'r': 0.2666999098084051}}
# top_k= 3
# Count: 256
# Ref: в иране по делу о крушении украинского « боинга » уже арестованы несколько человек . самолет был сбит по ошибке , роковую роль сыграл человеческий фактор , а ответственность за инцидент уже взяли на себя иранские военные .
# Hyp: первые аресты произошли в иране в связи с крушением boeing 737 « международных авиалиний украины » . об этом заявил официальный представитель иранской судебной власти голямхосейн эсмаили , передает риа « новости » . более подробной информации о личностях арестованных и их дальнейшей судьбе пока что нет .
# BLEU:  0.4393225852198937
# ROUGE:  {'rouge-1': {'f': 0.3065238935867477, 'p': 0.28833368357588457, 'r': 0.3471444940199835}, 'rouge-2': {'f': 0.1384072188546145, 'p': 0.1270066208602402, 'r': 0.164565228119747}, 'rouge-l': {'f': 0.26110955761314775, 'p': 0.2597052418820845, 'r': 0.31256954432056805}}
# top_k= 5
# Count: 256
# Hyp: известный хирург-онколог петербургской клиники высоких медицинских технологий имени н . и . пирогова андрей павленко написал прощальное письмо , в котором заявил , что его борьба с раком окончена . по словам медика , рак у него развился сильно буквально в последние два месяца . « друзья ! мой жизненный путь завершается ! к сожалению моя болезнь оказалась коварнее , и ее развитие за последние 2 месяца не оставило мне шансов ! но я хотел бы сейчас предупредить всех кто находится на этапе лечения — не опускайте руки ! статистика вещь упрямая и у вас даже с моим диагнозом есть шансы на излечение ! просто поверьте в это ! мне просто не повезло ) » , — написал врач в facebook . у павленко несколько лет назад был обнаружен рак желудка третьей стадии , он начал лечение и продолжал работать : оперировал и консультировал пациентов . даже после операции по полному удалению желудка он снова вышел на работу . также медик завел блог , где обсуждал проблемы онкологии . кроме того , доктор создал благотворительный проект cancerfund , направленный на улучшение качества онкологической помощи в россии . после этого актер и режиссер константин хабенский снял документальный фильм « полгода жизни андрея павленко » . в конце прошлого года ученые национального института онкологии сша выяснили , что физическая активность снижает риск развития рака . об этом сообщал портал medicalxpress . ученые изучили состояние 750 человек . исследование показало , что физическая активность снижает риск развития семи типов рака : толстой кишки у мужчин , молочной железы у женщин , эндометрии , почек , печени , меланомы и неходжкинской лимфомы . специалисты отметили , что 2,5 — 5 часов умеренных физических нагрузок или 1,25 — 2,5 часа высокоинтенсивных упражнений в неделю могут уменьшить риск появления онкологических заболеваний . двумя неделями ранее специалисты американского онкологического общества пришли к выводу , что снижение массы тела может уменьшить риска развития рака молочной железы . об этом информирует портал eurekalert !. в ходе исследования специалисты изучили данные о 180 тысячах женщин в возрасте 50 лет и старше . они замеряли их вес три раза на протяжении 10 лет : на первый , пятый и девятый год эксперимента . результаты показали , что с потерей веса снижалась вероятность развития онкологии . примечательно , что когда пациентки , которые уже находились в группе риска , худели , их шансы заболеть раком также становились ниже . женщины , потерявшие от 2 кг до 4,5 кг , снижали риск онкологии на 13 % , сбросившие от 4,5 кг до 9 кг — на 16 % , а похудевшие на 9 кг и больше уменьшали риски на 26 % . кроме того , ведущий автор исследования лорен терас добавил , что даже умеренная потеря веса провоцирует снижение риска развития рака молочной железы у женщин старше 50 лет . в середине прошлого месяца россияне назвали болезни , которые больше всего вызывают у них страх . об этом сообщалось в результатах опроса портала « здоровье mail . ru » . так , большинство опрошенных ( 69 % ) боятся рака .
# BLEU:  0.08012390202681806
# ROUGE:  {'rouge-1': {'f': 0.14718387144106973, 'p': 0.08339247108590996, 'r': 0.65808944818404}, 'rouge-2': {'f': 0.05345338743533255, 'p': 0.029343260042602435, 'r': 0.3193138153775776}, 'rouge-l': {'f': 0.0788376314089196, 'p': 0.07759106640925134, 'r': 0.61194327288723}}

# %% [markdown]
# ## Обучим модель с novelty и весами и оценим ее качество

# %%
model = SentenceTaggerRNN(vocab_size, use_novelty=True).to(device)

train_all(True, N_EPOCHS, CLIP)

model.load_state_dict(torch.load('best-val-model.pt'))

top_k_inference_summarunner(model, test_iterator, 1)
top_k_inference_summarunner(model, test_iterator, 2)
top_k_inference_summarunner(model, test_iterator, 3)
top_k_inference_summarunner(model, test_iterator, 5)
threshold_inference_summarunner(model, test_iterator, 0.2)
threshold_inference_summarunner(model, test_iterator, 0.3)
threshold_inference_summarunner(model, test_iterator, 0.35)
threshold_inference_summarunner(model, test_iterator, 0.4)
threshold_inference_summarunner(model, test_iterator, 0.5)
# Out:
# Epoch: 20 | Time: 0m 9s
# 	Train Loss: 0.175 | Train PPL:   1.191
# 	 Val. Loss: 2.318 |  Val. PPL:  10.160
# top_k= 1
# Count: 256
# Ref: экипаж корабля « союз мс-16 » , который должен в апреле отправиться к мкс , заменят на дублеров , сообщили в роскосмосе . такое решение принято по медицинским показаниям , связанным с подготовкой на земле . неизвестно , сможет ли основной экипаж полететь в космос в будущем .
# Hyp: российская часть экипажа корабля « союз мс-16 » , который должен лететь к международной космической станции ( мкс ) 9 апреля , будет заменена на дублеров , сообщает « риа новости » со ссылкой на исполнительного директора роскосмоса по пилотируемым программам сергея крикалева .
# BLEU:  0.1974612047722521
# ROUGE:  {'rouge-1': {'f': 0.2816651701712057, 'p': 0.4426591321651474, 'r': 0.2191164861780839}, 'rouge-2': {'f': 0.14088060542198777, 'p': 0.22634890714244002, 'r': 0.10919055716826957}, 'rouge-l': {'f': 0.21094895727342552, 'p': 0.3949881966030378, 'r': 0.19480953254794522}}
# top_k= 2
# Count: 256
# Ref: в москве задержали следователя по особо важным делам , который получил взятку в размере 4,3 млн руб . по данным столичного главка ск , сотрудник правоохранительных органов получил деньги от родственника одного из обвиняемых , проходящего по уголовному делу . взамен следователь обещал не привлекать его к уголовной ответственности .
# Hyp: в москве задержан следователь по особо важным делам — его обвиняют в получение взятки в 4,3 млн руб . ( часть 6 статьи 290 ук рф ) , сообщили в пресс-службе столичного главка ск . « 4 февраля следователь получил от лица , действующего под контролем сотрудников правоохранительных органов , взятку в размере 4,3 млн рублей .
# BLEU:  0.4314597064479413
# ROUGE:  {'rouge-1': {'f': 0.3084082709165302, 'p': 0.34336524696611187, 'r': 0.29756229004885976}, 'rouge-2': {'f': 0.14441688650970821, 'p': 0.15926624164693487, 'r': 0.14310604897980922}, 'rouge-l': {'f': 0.26069235894158593, 'p': 0.30867613967686514, 'r': 0.2666999098084053}}
# top_k= 3
# Count: 256
# Ref: россия и белоруссия близки к согласованию « дорожных карт » по углублению экономической интеграции , констатировал глава минэкономразвития рф максим орешкин . но стороны признают , что остались нерешенными два ключевых вопроса – общий энергетический рынок и введение единой валюты . без этих аспектов полноценное функционирование союзного государства невозможно , указывают аналитики .
# Hyp: москва и минск близки к завершению работы по согласованию « дорожных карт » по углублению экономической интеграции , заявил глава минэкономразвития рф максим орешкин в четверг в интервью телеканалу « россия-24 » . по его словам , россия и белоруссия близки к согласованию пакета из 31 дорожной карты по экономической интеграции . « это очень большой и сложный процесс , мы сейчас близки к тому , чтобы завершить эту работу » , — отметил чиновник .
# BLEU:  0.4393225852198937
# ROUGE:  {'rouge-1': {'f': 0.30652389358674786, 'p': 0.28833368357588474, 'r': 0.3471444940199836}, 'rouge-2': {'f': 0.13840721885461446, 'p': 0.1270066208602402, 'r': 0.16456522811974705}, 'rouge-l': {'f': 0.2611095576131479, 'p': 0.2597052418820846, 'r': 0.31256954432056777}}
# threshold 0.35
# Count: 256
# Ref: мид японии потребовал от россии вернуть пять задержанных рыболовецких судов . траулеры из хоккайдо ранее были задержаны во время ловли осьминога у курильских островов . российские пограничники осмотрели восемь судов , три из них направили в порт приписки .
# Hyp: министерство иностранных дел японии направило российским властям требование о возвращении пяти задержанных рыболовецких судов , пишет агентство kyodo . нота была передана москве по дипломатическим каналам , отметили в японском миде . « задержание судов неприемлемо .
# BLEU:  0.4562767795084694
# ROUGE:  {'rouge-1': {'f': 0.31102890706679376, 'p': 0.3029692056681351, 'r': 0.34047420640560394}, 'rouge-2': {'f': 0.1428836468487779, 'p': 0.13636642905281002, 'r': 0.162473521468878}, 'rouge-l': {'f': 0.26542806891994486, 'p': 0.27280471796308475, 'r': 0.3062184144682378}}
# threshold 0.4
# Count: 256
# Ref: в голландии в рамках борьбы с пиратством были отключены сервера плеера moonwalk . из-за этого россияне лишились доступа к крупным сайтам , которые нелегально распространяли фильмы и сериалы . между тем , статистика утверждает , что лишь 9 % пользователей выбирают лицензионный медиаконтент из-за ряда неудобств , с которыми приходится столкнуться .
# Hyp: сервера плеера moonwalk , используемого в 80 % российских пиратских стриминговых сайтах , были отключены в голландии , передает портал torrentfreak . сообщается , что это решение остановило работу таких популярных ресурсов , как baskino , hdrezka , kinogo , « гидонлайн » и некоторых других .
# BLEU:  0.4790679634274143
# ROUGE:  {'rouge-1': {'f': 0.31115174527853245, 'p': 0.31926216669700846, 'r': 0.32348875670044547}, 'rouge-2': {'f': 0.14357369501882952, 'p': 0.14573290470486452, 'r': 0.1538811785635389}, 'rouge-l': {'f': 0.2644912128784558, 'p': 0.2860069075965461, 'r': 0.28968638607367586}}
# threshold 0.5
# Count: 256
# Ref: « ред булл » собирался объявить состав пилотов на новый сезон на гран-при сша , но пока непонятно , выполнит ли это обещание . между этапами в мексике и на « трассе америк » консультант команды гельмут марко заявил о том , что даниил квят также претендует на место в главной команде , хотя ранее он был исключен из списка кандидатов . гонка в сша будет одним из шансов россиянина стать партнером макса ферстаппена .
# Hyp: уже когда даниил квят перед нынешним сезоном вернулся в « формулу-1 » , да еще и в программу « ред булл » , откуда чуть больше чем за год до возвращения был отчислен с фактической формулировкой « бесперспективный » , это выглядело невероятным . по ходу сезона , когда даниил начал показывать куда более зрелый пилотаж , чем в предыдущие годы , а также добиваться на « торо россо » шикарных результатов , включая сенсационный подиум на гран-при германии , ставший для « конюшни » всего вторым за всю историю ее существования ( в 2011 году молодой себастьян феттель выиграл в монце ) , показалось , что карьерный взлет может продолжиться .
# BLEU:  0.4329009527413664
# ROUGE:  {'rouge-1': {'f': 0.30825257185970656, 'p': 0.34250757752045363, 'r': 0.2968641810735257}, 'rouge-2': {'f': 0.1438113415175967, 'p': 0.1584991781130881, 'r': 0.14169474144301206}, 'rouge-l': {'f': 0.2610835544402882, 'p': 0.3082030736430577, 'r': 0.26594960106903753}}

# %% [markdown]
# ## Вывод:
# - использование весов улучшает результаты, когда используем threshold-based inference_summarunner
# - использование novelty не улучшает результат
# - максимальное значение BLEU, которого удалось достичь - это 0.47
